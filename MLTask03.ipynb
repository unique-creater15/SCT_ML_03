# %% [markdown]
# kaggle's alternative dataset download

# %%
# !wget --no-check-certificate \
  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip \
  -O /content/catsdogs.zip
# Out:
# --2026-07-23 14:26:21--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
# Resolving download.microsoft.com (download.microsoft.com)... 23.60.143.39, 2600:1408:ec00:e80::317f, 2600:1408:ec00:e82::317f
# Connecting to download.microsoft.com (download.microsoft.com)|23.60.143.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824887076 (787M) [application/octet-stream]
# Saving to: ‘/content/catsdogs.zip’
#
# /content/catsdogs.z 100%[===================>] 786.67M  47.3MB/s    in 8.6s
#
# 2026-07-23 14:26:30 (91.8 MB/s) - ‘/content/catsdogs.zip’ saved [824887076/824887076]

# %% [markdown]
# unzip it

# %%
# !unzip -q /content/catsdogs.zip -d /content/data

# %% [markdown]
# pictures in both cats and dogs sets

# %%
import os
print("Cats:", len(os.listdir('/content/data/PetImages/Cat')))
print("Dogs:", len(os.listdir('/content/data/PetImages/Dog')))
# Out:
# Cats: 12501
# Dogs: 12501

# %% [markdown]
# python files upload

# %%
from google.colab import files
files.upload()  # select the new svm_cats_dogs.py
# Out:
#      <input type="file" id="files-3670c06d-4c40-46db-86b2-88ac505b5d7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3670c06d-4c40-46db-86b2-88ac505b5d7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# train the svm model

# %%
# !python svm_cats_dogs.py --data_dir /content/data/PetImages --sample_size 4000 --n_components 200 --model_out svm_cats_dogs.joblib
# Out:
# Loading image paths...
# Total images: 4000 (cats: 2000, dogs: 2000)
# Extracting HOG features (this can take a few minutes)...
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
#   processed 500/4000 images
#   processed 1000/4000 images
#   processed 1500/4000 images
#   processed 2000/4000 images
# ...
#   processed 2500/4000 images
#   processed 3000/4000 images
#   processed 3500/4000 images
#   processed 4000/4000 images
# Feature extraction done in 16.2s. Feature vector length: 1764
# Scaling features...
# Reducing dimensionality with PCA (n_components=200)...
# Explained variance retained: 0.728
# Running grid search for best SVM hyperparameters...
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# Best params: {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# Evaluating on test set...
# Test accuracy: 0.7300
#               precision    recall  f1-score   support
#
#          cat       0.74      0.71      0.72       400
# ...

# %% [markdown]
# location of python file

# %%
# !ls svm_cats_dogs.py
# Out:
# svm_cats_dogs.py

# %% [markdown]
# download this joblib file

# %%
from google.colab import files
files.download('svm_cats_dogs.joblib')

# %% [markdown]
# accuracy prediction

# %%
from svm_cats_dogs import predict_image
predict_image('/content/data/PetImages/Cat/100.jpg', 'svm_cats_dogs.joblib')
predict_image('/content/data/PetImages/Dog/100.jpg', 'svm_cats_dogs.joblib')
# Out:
# /content/data/PetImages/Cat/100.jpg -> predicted: cat
# /content/data/PetImages/Dog/100.jpg -> predicted: dog
# 'dog'
